# %% [markdown]
# ### This notebook is the benchmark notebook, where test results of each test notebook is combined together

# %%
def plot_results(benchmark,normalize = True):
    if normalize:
        benchmark_norm = benchmark.iloc[:,2:-3].div(benchmark.sum(axis=1), axis=0)
        key = 'Normalized'
    else:
        benchmark_norm = benchmark.iloc[:,2:-3]
        key = 'Un-Normalized'
    plt.figure()
    y = np.arange(len(benchmark_norm.columns))
    col_labels = np.array(benchmark_norm.columns)
    for i in range(len(benchmark)):
        y_pos = y + i * (1/(2*len(col_labels)))
        plt.barh(y_pos,benchmark_norm.iloc[i,:],height = 1/(2*len(col_labels)),label = benchmark['Data_Type'][i] +  benchmark['Explainer_Type'][i][:3] +benchmark['Model_Type'][i][:3])
    plt.yticks([r + (1/(len(col_labels))) for r in range(len(y))], col_labels)
    plt.legend()
    plt.title(key + ' test errors in different datasets vs. method used (Trained over {0} via explainer {1} & model {2})'.format(benchmark.iloc[0,-3],benchmark.iloc[0,-2],benchmark.iloc[0,-1]))

# %%
from os import listdir
#%run "Shapley_Clustering_Boston_Dataset.ipynb"
#%run "Shapley_Clustering_Crime_Dataset.ipynb"

for c in [0,3,4,6,7]:
    for nC in [2,4]:
        for i in ['Original']:
            for j in ['Linear']:
                for k in ['XGBoost']:
                    # !python Shapley_Clustering_Blackbox.py $i $j $k $nC $c
# Out:
# C:\Users\koral\Google Drive\KUL\Thesis\Software\Notebooks
# <IPython.core.display.HTML object>
# [0]	train-rmse:0.658993	test-rmse:0.621582
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [1884]	train-rmse:0.190838	test-rmse:0.304733
#
# [0]	train-rmse:1.39573	test-rmse:1.27438
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [379]	train-rmse:0.483649	test-rmse:0.516755
#
# [0]	train-rmse:0.707369	test-rmse:0.604868
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [386]	train-rmse:0.315359	test-rmse:0.3537
#
# [0]	train-rmse:1.41923	test-rmse:1.36817
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [437]	train-rmse:0.450271	test-rmse:0.507116
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# C:\Users\koral\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# Shapley_Clustering_Blackbox.py:72: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   X_train = pd.DataFrame(scaler.transform(X_train),columns = X.columns)
# Shapley_Clustering_Blackbox.py:73: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   X_test = pd.DataFrame(scaler.transform(X_test),columns = X.columns)
# C:\Users\koral\Anaconda3\lib\site-packages\shap\explainers\linear.py:49: UserWarning: The default value for feature_dependence has been changed to "independent"!
#   warnings.warn('The default value for feature_dependence has been changed to "independent"!')
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Shapley_Clustering_Blackbox.py:180: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_tr.sort_index(inplace = True)
# Shapley_Clustering_Blackbox.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_val.sort_index(inplace = True)
# C:\Users\koral\Google Drive\KUL\Thesis\Software\Notebooks
# <IPython.core.display.HTML object>
# [0]	train-rmse:1.10672	test-rmse:0.853399
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [314]	train-rmse:0.440803	test-rmse:0.322622
#
# [0]	train-rmse:0.594833	test-rmse:0.60969
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [397]	train-rmse:0.339802	test-rmse:0.449488
#
# [0]	train-rmse:1.73247	test-rmse:1.73763
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [421]	train-rmse:0.440219	test-rmse:0.568191
#
# [0]	train-rmse:0.774262	test-rmse:0.787067
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [1135]	train-rmse:0.128218	test-rmse:0.127233
#
# [0]	train-rmse:1.93308	test-rmse:1.94576
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [440]	train-rmse:0.486488	test-rmse:0.434965
#
# [0]	train-rmse:0.523782	test-rmse:0.389371
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [144]	train-rmse:0.393904	test-rmse:0.346832
#
# [0]	train-rmse:0.891783	test-rmse:0.968733
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [988]	train-rmse:0.076091	test-rmse:0.11444
#
# [0]	train-rmse:1.01199	test-rmse:1.03061
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [311]	train-rmse:0.431019	test-rmse:0.553398
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# C:\Users\koral\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# Shapley_Clustering_Blackbox.py:72: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   X_train = pd.DataFrame(scaler.transform(X_train),columns = X.columns)
# Shapley_Clustering_Blackbox.py:73: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   X_test = pd.DataFrame(scaler.transform(X_test),columns = X.columns)
# C:\Users\koral\Anaconda3\lib\site-packages\shap\explainers\linear.py:49: UserWarning: The default value for feature_dependence has been changed to "independent"!
#   warnings.warn('The default value for feature_dependence has been changed to "independent"!')
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Shapley_Clustering_Blackbox.py:180: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_tr.sort_index(inplace = True)
# Shapley_Clustering_Blackbox.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_val.sort_index(inplace = True)
# C:\Users\koral\Google Drive\KUL\Thesis\Software\Notebooks
# <IPython.core.display.HTML object>
# [0]	train-rmse:1.09094	test-rmse:1.1136
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [471]	train-rmse:0.270327	test-rmse:0.354871
#
# [0]	train-rmse:1.13464	test-rmse:1.08844
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [1306]	train-rmse:0.658433	test-rmse:0.646412
#
# [0]	train-rmse:1.11559	test-rmse:1.09094
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [408]	train-rmse:0.363585	test-rmse:0.464637
#
# [0]	train-rmse:1.1158	test-rmse:1.106
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [746]	train-rmse:0.613783	test-rmse:0.567935
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# C:\Users\koral\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# Shapley_Clustering_Blackbox.py:72: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   X_train = pd.DataFrame(scaler.transform(X_train),columns = X.columns)
# Shapley_Clustering_Blackbox.py:73: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   X_test = pd.DataFrame(scaler.transform(X_test),columns = X.columns)
# C:\Users\koral\Anaconda3\lib\site-packages\shap\explainers\linear.py:49: UserWarning: The default value for feature_dependence has been changed to "independent"!
#   warnings.warn('The default value for feature_dependence has been changed to "independent"!')
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Shapley_Clustering_Blackbox.py:180: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_tr.sort_index(inplace = True)
# Shapley_Clustering_Blackbox.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_val.sort_index(inplace = True)
# C:\Users\koral\Google Drive\KUL\Thesis\Software\Notebooks
# <IPython.core.display.HTML object>
# [0]	train-rmse:1.14567	test-rmse:1.16803
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [314]	train-rmse:0.246155	test-rmse:0.435921
#
# [0]	train-rmse:1.13645	test-rmse:1.06254
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [765]	train-rmse:0.699011	test-rmse:0.689843
#
# [0]	train-rmse:1.23099	test-rmse:1.28846
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [914]	train-rmse:0.382591	test-rmse:0.672334
#
# [0]	train-rmse:1.04583	test-rmse:1.0507
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [426]	train-rmse:0.347659	test-rmse:0.324798
#
# [0]	train-rmse:1.1222	test-rmse:1.05386
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [749]	train-rmse:0.673455	test-rmse:0.590874
#
# [0]	train-rmse:1.13613	test-rmse:1.14331
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [317]	train-rmse:0.265182	test-rmse:0.530921
#
# [0]	train-rmse:1.10994	test-rmse:1.17048
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [858]	train-rmse:0.398155	test-rmse:0.510925
#
# [0]	train-rmse:1.10114	test-rmse:1.06564
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [484]	train-rmse:0.329987	test-rmse:0.400717
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# C:\Users\koral\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# Shapley_Clustering_Blackbox.py:72: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   X_train = pd.DataFrame(scaler.transform(X_train),columns = X.columns)
# Shapley_Clustering_Blackbox.py:73: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   X_test = pd.DataFrame(scaler.transform(X_test),columns = X.columns)
# C:\Users\koral\Anaconda3\lib\site-packages\shap\explainers\linear.py:49: UserWarning: The default value for feature_dependence has been changed to "independent"!
#   warnings.warn('The default value for feature_dependence has been changed to "independent"!')
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Shapley_Clustering_Blackbox.py:180: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_tr.sort_index(inplace = True)
# Shapley_Clustering_Blackbox.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_val.sort_index(inplace = True)
# C:\Users\koral\Google Drive\KUL\Thesis\Software\Notebooks
# <IPython.core.display.HTML object>
# [0]	train-rmse:1.27242	test-rmse:1.21396
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [649]	train-rmse:0.539018	test-rmse:0.71512
#
# [0]	train-rmse:0.971586	test-rmse:0.909209
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [437]	train-rmse:0.643839	test-rmse:0.704548
#
# [0]	train-rmse:1.24984	test-rmse:1.16542
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [271]	train-rmse:0.603972	test-rmse:0.730929
#
# [0]	train-rmse:0.939748	test-rmse:0.904798
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [311]	train-rmse:0.668423	test-rmse:0.735719
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# C:\Users\koral\Anaconda3\lib\site-packages\shap\explainers\linear.py:49: UserWarning: The default value for feature_dependence has been changed to "independent"!
#   warnings.warn('The default value for feature_dependence has been changed to "independent"!')
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Shapley_Clustering_Blackbox.py:180: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_tr.sort_index(inplace = True)
# Shapley_Clustering_Blackbox.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_val.sort_index(inplace = True)
# C:\Users\koral\Google Drive\KUL\Thesis\Software\Notebooks
# <IPython.core.display.HTML object>
# [0]	train-rmse:1.11069	test-rmse:1.06619
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [337]	train-rmse:0.683068	test-rmse:0.801541
#
# [0]	train-rmse:1.24995	test-rmse:1.20945
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [284]	train-rmse:0.486909	test-rmse:0.547446
#
# [0]	train-rmse:0.846061	test-rmse:0.843663
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [429]	train-rmse:0.553752	test-rmse:0.696781
#
# [0]	train-rmse:1.26697	test-rmse:1.08957
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [303]	train-rmse:0.49098	test-rmse:0.762546
#
# [0]	train-rmse:1.34504	test-rmse:1.13906
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [252]	train-rmse:0.51699	test-rmse:0.742428
#
# [0]	train-rmse:1.0293	test-rmse:0.99305
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [191]	train-rmse:0.727768	test-rmse:0.925369
#
# [0]	train-rmse:0.820174	test-rmse:0.86576
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [582]	train-rmse:0.43161	test-rmse:0.737865
#
# [0]	train-rmse:1.14307	test-rmse:1.14085
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [334]	train-rmse:0.566365	test-rmse:0.666136
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# C:\Users\koral\Anaconda3\lib\site-packages\shap\explainers\linear.py:49: UserWarning: The default value for feature_dependence has been changed to "independent"!
#   warnings.warn('The default value for feature_dependence has been changed to "independent"!')
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Shapley_Clustering_Blackbox.py:180: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_tr.sort_index(inplace = True)
# Shapley_Clustering_Blackbox.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_val.sort_index(inplace = True)
# C:\Users\koral\Google Drive\KUL\Thesis\Software\Notebooks
# <IPython.core.display.HTML object>
# [0]	train-rmse:1.01588	test-rmse:1.03378
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [604]	train-rmse:0.383788	test-rmse:0.382238
#
# [0]	train-rmse:1.39899	test-rmse:1.4017
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [579]	train-rmse:0.313913	test-rmse:0.335829
#
# [0]	train-rmse:1.01588	test-rmse:1.03378
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [604]	train-rmse:0.383788	test-rmse:0.382238
#
# [0]	train-rmse:1.39899	test-rmse:1.4017
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [579]	train-rmse:0.313913	test-rmse:0.335829
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# C:\Users\koral\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# Shapley_Clustering_Blackbox.py:72: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   X_train = pd.DataFrame(scaler.transform(X_train),columns = X.columns)
# Shapley_Clustering_Blackbox.py:73: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   X_test = pd.DataFrame(scaler.transform(X_test),columns = X.columns)
# C:\Users\koral\Anaconda3\lib\site-packages\shap\explainers\linear.py:49: UserWarning: The default value for feature_dependence has been changed to "independent"!
#   warnings.warn('The default value for feature_dependence has been changed to "independent"!')
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Shapley_Clustering_Blackbox.py:180: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_tr.sort_index(inplace = True)
# Shapley_Clustering_Blackbox.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_val.sort_index(inplace = True)
# C:\Users\koral\Google Drive\KUL\Thesis\Software\Notebooks
# <IPython.core.display.HTML object>
# [0]	train-rmse:1.04648	test-rmse:1.03693
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [786]	train-rmse:0.347434	test-rmse:0.407667
#
# [0]	train-rmse:1.39899	test-rmse:1.4017
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [579]	train-rmse:0.313913	test-rmse:0.335829
#
# [0]	train-rmse:1.05379	test-rmse:1.09825
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [513]	train-rmse:0.390274	test-rmse:0.412141
#
# [0]	train-rmse:0.873143	test-rmse:0.91091
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [597]	train-rmse:0.379653	test-rmse:0.268042
#
# [0]	train-rmse:0.762131	test-rmse:0.791991
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [471]	train-rmse:0.391446	test-rmse:0.384588
#
# [0]	train-rmse:1.63006	test-rmse:1.53463
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [448]	train-rmse:0.329715	test-rmse:0.376519
#
# [0]	train-rmse:1.17136	test-rmse:1.25425
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [388]	train-rmse:0.285074	test-rmse:0.321056
#
# [0]	train-rmse:1.23384	test-rmse:1.25347
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [426]	train-rmse:0.371001	test-rmse:0.393264
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# C:\Users\koral\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# Shapley_Clustering_Blackbox.py:72: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   X_train = pd.DataFrame(scaler.transform(X_train),columns = X.columns)
# Shapley_Clustering_Blackbox.py:73: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   X_test = pd.DataFrame(scaler.transform(X_test),columns = X.columns)
# C:\Users\koral\Anaconda3\lib\site-packages\shap\explainers\linear.py:49: UserWarning: The default value for feature_dependence has been changed to "independent"!
#   warnings.warn('The default value for feature_dependence has been changed to "independent"!')
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Shapley_Clustering_Blackbox.py:180: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_tr.sort_index(inplace = True)
# Shapley_Clustering_Blackbox.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_val.sort_index(inplace = True)
# C:\Users\koral\Google Drive\KUL\Thesis\Software\Notebooks
# <IPython.core.display.HTML object>
# [0]	train-rmse:1.16792	test-rmse:1.17369
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [905]	train-rmse:0.682556	test-rmse:0.735481
#
# [0]	train-rmse:1.01941	test-rmse:1.02633
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [941]	train-rmse:0.908226	test-rmse:0.92461
#
# [0]	train-rmse:1.18149	test-rmse:1.1894
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [436]	train-rmse:0.651568	test-rmse:0.672888
#
# [0]	train-rmse:1.02447	test-rmse:1.0247
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [747]	train-rmse:0.916231	test-rmse:0.9557
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# C:\Users\koral\Anaconda3\lib\site-packages\shap\explainers\linear.py:49: UserWarning: The default value for feature_dependence has been changed to "independent"!
#   warnings.warn('The default value for feature_dependence has been changed to "independent"!')
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Shapley_Clustering_Blackbox.py:180: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_tr.sort_index(inplace = True)
# Shapley_Clustering_Blackbox.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_val.sort_index(inplace = True)
# C:\Users\koral\Google Drive\KUL\Thesis\Software\Notebooks
# <IPython.core.display.HTML object>
# [0]	train-rmse:1.1537	test-rmse:1.17029
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [585]	train-rmse:0.742825	test-rmse:0.790975
#
# [0]	train-rmse:1.11515	test-rmse:1.11165
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [655]	train-rmse:0.809511	test-rmse:0.839203
#
# [0]	train-rmse:1.1713	test-rmse:1.17153
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [346]	train-rmse:0.652826	test-rmse:0.70343
#
# [0]	train-rmse:1.00157	test-rmse:1.01292
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [600]	train-rmse:0.897584	test-rmse:0.92362
#
# [0]	train-rmse:1.16243	test-rmse:1.15573
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [754]	train-rmse:0.904093	test-rmse:0.990608
#
# [0]	train-rmse:0.96888	test-rmse:0.973497
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [727]	train-rmse:0.893176	test-rmse:0.919118
#
# [0]	train-rmse:1.17349	test-rmse:1.16125
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [287]	train-rmse:0.526469	test-rmse:0.58575
#
# [0]	train-rmse:1.19052	test-rmse:1.21645
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [393]	train-rmse:0.693424	test-rmse:0.711947
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# C:\Users\koral\Anaconda3\lib\site-packages\shap\explainers\linear.py:49: UserWarning: The default value for feature_dependence has been changed to "independent"!
#   warnings.warn('The default value for feature_dependence has been changed to "independent"!')
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Shapley_Clustering_Blackbox.py:180: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_tr.sort_index(inplace = True)
# Shapley_Clustering_Blackbox.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_val.sort_index(inplace = True)

# %%
import shap
for i in range(3,4):
    # !python Shapley_Clustering_Blackbox.py Original Linear XGBoost 2 $i
# Out:
# C:\Users\koral\Google Drive\KUL\Thesis\Software\Notebooks
# <IPython.core.display.HTML object>
# [0]	train-rmse:1.09094	test-rmse:1.1136
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [471]	train-rmse:0.270327	test-rmse:0.354871
#
# [0]	train-rmse:1.13464	test-rmse:1.08844
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [1306]	train-rmse:0.658433	test-rmse:0.646412
#
# [0]	train-rmse:1.11559	test-rmse:1.09094
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [408]	train-rmse:0.363585	test-rmse:0.464637
#
# [0]	train-rmse:1.1158	test-rmse:1.106
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [746]	train-rmse:0.613783	test-rmse:0.567935
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# C:\Users\koral\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# Shapley_Clustering_Blackbox.py:72: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   X_train = pd.DataFrame(scaler.transform(X_train),columns = X.columns)
# Shapley_Clustering_Blackbox.py:73: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   X_test = pd.DataFrame(scaler.transform(X_test),columns = X.columns)
# C:\Users\koral\Anaconda3\lib\site-packages\shap\explainers\linear.py:49: UserWarning: The default value for feature_dependence has been changed to "independent"!
#   warnings.warn('The default value for feature_dependence has been changed to "independent"!')
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Shapley_Clustering_Blackbox.py:180: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_tr.sort_index(inplace = True)
# Shapley_Clustering_Blackbox.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   X_train_val.sort_index(inplace = True)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
benchmark_df = pd.read_csv('../Data/test_scaled.txt')

# %%
bsl1 = benchmark_df.groupby('Dataset_name').agg({'Explainer_model' : min})
bsl2 = benchmark_df.groupby('Dataset_name').agg({'Original_ensemble' : min})
bsl1
# Out:
#                 Explainer_model
# Dataset_name
# Amazon                    0.927
# Boston                    0.545
# Crime                     0.652
# Diabetes                  0.743
# Fish_weights              0.171
# Insurance                 0.471
# NYE_Airbnb                0.832
# Nhanes                    0.804
# Student_grades            0.495

# %%
bsl2
# Out:
#                 Original_ensemble
# Dataset_name
# Amazon                      0.911
# Boston                      0.497
# Crime                       0.646
# Diabetes                    0.743
# Fish_weights                0.171
# Insurance                   0.329
# NYE_Airbnb                  0.809
# Nhanes                      0.804
# Student_grades              0.495

# %%
for j in range(len(benchmark_df['Dataset_name'])):
    benchmark_df['Explainer_model'].iloc[j] = bsl1.loc[benchmark_df['Dataset_name'].iloc[j]][0]
    benchmark_df['Original_ensemble'].iloc[j] = bsl2.loc[benchmark_df['Dataset_name'].iloc[j]][0]
# Out:
# C:\Users\koral\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
benchmark_df_min = benchmark_df[(benchmark_df['Explainer_model'] > benchmark_df['Shapley_ensemble']) & (benchmark_df['Original_ensemble'] > benchmark_df['Shapley_ensemble'])]
bsl1_improvement = (benchmark_df_min['Explainer_model'] - benchmark_df_min['Shapley_ensemble']).divide(benchmark_df_min['Explainer_model'])
bsl2_improvement = (benchmark_df_min['Original_ensemble'] - benchmark_df_min['Shapley_ensemble']).divide(benchmark_df_min['Original_ensemble'])
benchmark_df_min['Percentage_Improvement'] = round(100 * (bsl1_improvement+bsl2_improvement)/2,1)
benchmark_df_min = benchmark_df_min.loc[benchmark_df_min['Percentage_Improvement'] > 0]
benchmark_df_min
# Out:
# C:\Users\koral\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#        Dataset_name  Explainer_model  Original_ensemble  Shapley_ensemble  \
# 8            Amazon            0.927              0.911             0.905
# 10           Amazon            0.927              0.911             0.887
# 14           Amazon            0.927              0.911             0.887
# 16           Amazon            0.927              0.911             0.899
# 18           Amazon            0.927              0.911             0.891
# 22           Amazon            0.927              0.911             0.891
# 32           Boston            0.545              0.497             0.476
# 36           Boston            0.545              0.497             0.420
# 37           Boston            0.545              0.497             0.424
# 42           Boston            0.545              0.497             0.384
# 43           Boston            0.545              0.497             0.480
# 45           Boston            0.545              0.497             0.437
# 46           Boston            0.545              0.497             0.384
# 47           Boston            0.545              0.497             0.480
# 80         Diabetes            0.743              0.743             0.741
# 84         Diabetes            0.743              0.743             0.738
# 88         Diabetes            0.743              0.743             0.738
# 92         Diabetes            0.743              0.743             0.722
# 106    Fish_weights            0.171              0.171             0.167
# 110    Fish_weights            0.171              0.171             0.167
# 180      NYE_Airbnb            0.832              0.809             0.804
# 192  Student_grades            0.495              0.495             0.487
# 193  Student_grades            0.495              0.495             0.489
# 194  Student_grades            0.495              0.495             0.494
# 196  Student_grades            0.495              0.495             0.467
# 198  Student_grades            0.495              0.495             0.457
# 200  Student_grades            0.495              0.495             0.449
# 201  Student_grades            0.495              0.495             0.478
# 202  Student_grades            0.495              0.495             0.457
# 208  Student_grades            0.495              0.495             0.494
#
#      Cluster_count Data_Type Explainer_Type Ensemble_model_Type  \
# 8                3  Original        XGBoost             XGBoost
# 10               3  Original         Linear             XGBoost
# 14               3   Shapley         Linear             XGBoost
# 16               5  Original        XGBoost             XGBoost
# 18               5  Original         Linear             XGBoost
# 22               5   Shapley         Linear             XGBoost
# 32               3  Original        XGBoost             XGBoost
# 36               3   Shapley        XGBoost             XGBoost
# 37               3   Shapley        XGBoost              Linear
# 42               5  Original         Linear             XGBoost
# 43               5  Original         Linear              Linear
# 45               5   Shapley        XGBoost              Linear
# 46               5   Shapley         Linear             XGBoost
# 47               5   Shapley         Linear              Linear
# 80               3  Original        XGBoost             XGBoost
# 84               3   Shapley        XGBoost             XGBoost
# 88               5  Original        XGBoost             XGBoost
# 92               5   Shapley        XGBoost             XGBoost
# 106              3  Original         Linear             XGBoost
# 110              3   Shapley         Linear             XGBoost
# 180              5  Original        XGBoost             XGBoost
# 192              1   Shapley        XGBoost             XGBoost
# 193              1   Shapley        XGBoost              Linear
# 194              1   Shapley         Linear             XGBoost
# 196              3  Original        XGBoost             XGBoost
# 198              3  Original         Linear             XGBoost
# 200              3   Shapley        XGBoost             XGBoost
# 201              3   Shapley        XGBoost              Linear
# 202              3   Shapley         Linear             XGBoost
# 208              5   Shapley        XGBoost             XGBoost
#
#      Percentage_Improvement
# 8                       1.5
# 10                      3.5
# 14                      3.5
# 16                      2.2
# 18                      3.0
# 22                      3.0
# 32                      8.4
# 36                     19.2
# 37                     18.4
# 42                     26.1
# 43                      7.7
# 45                     15.9
# 46                     26.1
# 47                      7.7
# 80                      0.3
# 84                      0.7
# 88                      0.7
# 92                      2.8
# 106                     2.3
# 110                     2.3
# 180                     2.0
# 192                     1.6
# 193                     1.2
# 194                     0.2
# 196                     5.7
# 198                     7.7
# 200                     9.3
# 201                     3.4
# 202                     7.7
# 208                     0.2

# %%
bench_datatype_grouped = benchmark_df_min.groupby('Data_Type').agg({'Percentage_Improvement':np.mean})
bench_dataset_grouped = benchmark_df_min.groupby(['Dataset_name']).agg({'Percentage_Improvement':np.mean, 'Data_Type':'nunique'})
bench_dataset_grouped = bench_dataset_grouped[bench_dataset_grouped['Data_Type'] == 1]
benchmark_df_min = benchmark_df_min[benchmark_df_min['Dataset_name'] != 'NYE_Airbnb']
# Out:
#        Dataset_name  Explainer_model  Original_ensemble  Shapley_ensemble  \
# 8            Amazon            0.927              0.911             0.905
# 10           Amazon            0.927              0.911             0.887
# 14           Amazon            0.927              0.911             0.887
# 16           Amazon            0.927              0.911             0.899
# 18           Amazon            0.927              0.911             0.891
# 22           Amazon            0.927              0.911             0.891
# 32           Boston            0.545              0.497             0.476
# 36           Boston            0.545              0.497             0.420
# 37           Boston            0.545              0.497             0.424
# 42           Boston            0.545              0.497             0.384
# 43           Boston            0.545              0.497             0.480
# 45           Boston            0.545              0.497             0.437
# 46           Boston            0.545              0.497             0.384
# 47           Boston            0.545              0.497             0.480
# 80         Diabetes            0.743              0.743             0.741
# 84         Diabetes            0.743              0.743             0.738
# 88         Diabetes            0.743              0.743             0.738
# 92         Diabetes            0.743              0.743             0.722
# 106    Fish_weights            0.171              0.171             0.167
# 110    Fish_weights            0.171              0.171             0.167
# 192  Student_grades            0.495              0.495             0.487
# 193  Student_grades            0.495              0.495             0.489
# 194  Student_grades            0.495              0.495             0.494
# 196  Student_grades            0.495              0.495             0.467
# 198  Student_grades            0.495              0.495             0.457
# 200  Student_grades            0.495              0.495             0.449
# 201  Student_grades            0.495              0.495             0.478
# 202  Student_grades            0.495              0.495             0.457
# 208  Student_grades            0.495              0.495             0.494
#
#      Cluster_count Data_Type Explainer_Type Ensemble_model_Type  \
# 8                3  Original        XGBoost             XGBoost
# 10               3  Original         Linear             XGBoost
# 14               3   Shapley         Linear             XGBoost
# 16               5  Original        XGBoost             XGBoost
# 18               5  Original         Linear             XGBoost
# 22               5   Shapley         Linear             XGBoost
# 32               3  Original        XGBoost             XGBoost
# 36               3   Shapley        XGBoost             XGBoost
# 37               3   Shapley        XGBoost              Linear
# 42               5  Original         Linear             XGBoost
# 43               5  Original         Linear              Linear
# 45               5   Shapley        XGBoost              Linear
# 46               5   Shapley         Linear             XGBoost
# 47               5   Shapley         Linear              Linear
# 80               3  Original        XGBoost             XGBoost
# 84               3   Shapley        XGBoost             XGBoost
# 88               5  Original        XGBoost             XGBoost
# 92               5   Shapley        XGBoost             XGBoost
# 106              3  Original         Linear             XGBoost
# 110              3   Shapley         Linear             XGBoost
# 192              1   Shapley        XGBoost             XGBoost
# 193              1   Shapley        XGBoost              Linear
# 194              1   Shapley         Linear             XGBoost
# 196              3  Original        XGBoost             XGBoost
# 198              3  Original         Linear             XGBoost
# 200              3   Shapley        XGBoost             XGBoost
# 201              3   Shapley        XGBoost              Linear
# 202              3   Shapley         Linear             XGBoost
# 208              5   Shapley        XGBoost             XGBoost
#
#      Percentage_Improvement
# 8                       1.5
# 10                      3.5
# 14                      3.5
# 16                      2.2
# 18                      3.0
# 22                      3.0
# 32                      8.4
# 36                     19.2
# 37                     18.4
# 42                     26.1
# 43                      7.7
# 45                     15.9
# 46                     26.1
# 47                      7.7
# 80                      0.3
# 84                      0.7
# 88                      0.7
# 92                      2.8
# 106                     2.3
# 110                     2.3
# 192                     1.6
# 193                     1.2
# 194                     0.2
# 196                     5.7
# 198                     7.7
# 200                     9.3
# 201                     3.4
# 202                     7.7
# 208                     0.2

# %%
g = sns.barplot(y =bench_datatype_grouped.index ,x ='Percentage_Improvement',data = bench_datatype_grouped)
g.set_title ('Percentage improvement over all methods and datasets for given feature space')
# Out:
# Text(0.5, 1.0, 'Percentage improvement over all methods and datasets for given feature space')

# %%
g= sns.barplot(y =bench_dataset_grouped.index ,x ='Percentage_Improvement',data = bench_dataset_grouped)
g.set_title('Percentage improvement in rmse over all models for given dataset')
# Out:
# Text(0.5, 1.0, 'Percentage improvement in rmse over all models for given dataset')

# %%
data_min = benchmark_df_min.groupby(['Data_Type','Explainer_Type','Ensemble_model_Type']).agg({'Dataset_name':'nunique','Percentage_Improvement':np.mean})
data_min['Percentage_Improvement'] = round(data_min['Percentage_Improvement'],1)
data_min.columns = ['Dataset_count','Percentage_Improvement']
best_params = data_min['Dataset_count'].idxmax()

# %%
data_min
# Out:
#                                               Dataset_count  \
# Data_Type Explainer_Type Ensemble_model_Type
# Original  Linear         Linear                           1
#                          XGBoost                          4
#           XGBoost        XGBoost                          5
# Shapley   Linear         Linear                           1
#                          XGBoost                          4
#           XGBoost        Linear                           2
#                          XGBoost                          3
#
#                                               Percentage_Improvement
# Data_Type Explainer_Type Ensemble_model_Type
# Original  Linear         Linear                                  7.7
#                          XGBoost                                 8.5
#           XGBoost        XGBoost                                 3.0
# Shapley   Linear         Linear                                  7.7
#                          XGBoost                                 7.1
#           XGBoost        Linear                                  9.7
#                          XGBoost                                 5.6

# %%
params_grouped = benchmark_df_min.groupby(['Data_Type','Explainer_Type','Ensemble_model_Type','Dataset_name'])
params_grouped_df = params_grouped.agg({'Explainer_model' : min ,'Original_ensemble':min, 'Shapley_ensemble' : min,'Percentage_Improvement':np.mean})
best_params_results = params_grouped_df.loc[best_params]

# %%
best_params_results
# Out:
#                 Explainer_model  Original_ensemble  Shapley_ensemble  \
# Dataset_name
# Amazon                    0.927              0.911             0.899
# Boston                    0.545              0.497             0.476
# Diabetes                  0.743              0.743             0.738
# NYE_Airbnb                0.832              0.809             0.804
# Student_grades            0.495              0.495             0.467
#
#                 Percentage_Improvement
# Dataset_name
# Amazon                            1.85
# Boston                            8.40
# Diabetes                          0.50
# NYE_Airbnb                        2.00
# Student_grades                    5.70

# %%
g = sns.barplot(y =best_params_results.index ,x ='Percentage_Improvement',data = best_params_results)
g.set_title('Percentage improvement in rmse for Feature Space: {0} /Explainer: {1} /Leaf_Model: {2}'.format(best_params[0],best_params[1],best_params[2]))
# Out:
# Text(0.5, 1.0, 'Percentage improvement in rmse for Feature Space: Original /Explainer: XGBoost /Leaf_Model: XGBoost')

# %%
data_min = benchmark_df.groupby(['Data_Type','Explainer_Type','Ensemble_model_Type','Dataset_name'])
data_min_df = data_min.agg({'Explainer_model' : min ,'Original_ensemble':min, 'Shapley_ensemble' : min})
data_real_min = data_min_df[(data_min_df['Explainer_model'] > data_min_df['Shapley_ensemble']) & (data_min_df['Original_ensemble'] > data_min_df['Shapley_ensemble'])]
bsl1_improvement = (data_real_min['Explainer_model'] - data_real_min['Shapley_ensemble']).divide(data_real_min['Explainer_model'])
bsl2_improvement = (data_real_min['Original_ensemble'] - data_real_min['Shapley_ensemble']).divide(data_real_min['Original_ensemble'])
data_real_min['Avg_Percentage_Improvement'] = 100 * (bsl1_improvement+bsl2_improvement)/2
data_real_min
# Out:
# C:\Users\koral\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                              Explainer_model  \
# Data_Type Explainer_Type Ensemble_model_Type Dataset_name
# Original  Linear         Linear              Boston                    0.545
#                          XGBoost             Amazon                    0.927
#                                              Boston                    0.545
#                                              Fish_weights              0.171
#                                              Student_grades            0.495
#           XGBoost        XGBoost             Amazon                    0.927
#                                              Boston                    0.545
#                                              Diabetes                  0.743
#                                              NYE_Airbnb                0.832
#                                              Student_grades            0.495
# Shapley   Linear         Linear              Boston                    0.545
#                          XGBoost             Amazon                    0.927
#                                              Boston                    0.545
#                                              Fish_weights              0.171
#                                              Student_grades            0.495
#           XGBoost        Linear              Boston                    0.545
#                                              Student_grades            0.495
#                          XGBoost             Boston                    0.545
#                                              Diabetes                  0.743
#                                              Student_grades            0.495
#
#                                                              Original_ensemble  \
# Data_Type Explainer_Type Ensemble_model_Type Dataset_name
# Original  Linear         Linear              Boston                      0.497
#                          XGBoost             Amazon                      0.911
#                                              Boston                      0.497
#                                              Fish_weights                0.171
#                                              Student_grades              0.495
#           XGBoost        XGBoost             Amazon                      0.911
#                                              Boston                      0.497
#                                              Diabetes                    0.743
#                                              NYE_Airbnb                  0.809
#                                              Student_grades              0.495
# Shapley   Linear         Linear              Boston                      0.497
#                          XGBoost             Amazon                      0.911
#                                              Boston                      0.497
#                                              Fish_weights                0.171
#                                              Student_grades              0.495
#           XGBoost        Linear              Boston                      0.497
#                                              Student_grades              0.495
#                          XGBoost             Boston                      0.497
#                                              Diabetes                    0.743
#                                              Student_grades              0.495
#
#                                                              Shapley_ensemble  \
# Data_Type Explainer_Type Ensemble_model_Type Dataset_name
# Original  Linear         Linear              Boston                     0.480
#                          XGBoost             Amazon                     0.887
#                                              Boston                     0.384
#                                              Fish_weights               0.167
#                                              Student_grades             0.457
#           XGBoost        XGBoost             Amazon                     0.899
#                                              Boston                     0.476
#                                              Diabetes                   0.738
#                                              NYE_Airbnb                 0.804
#                                              Student_grades             0.467
# Shapley   Linear         Linear              Boston                     0.480
#                          XGBoost             Amazon                     0.887
#                                              Boston                     0.384
#                                              Fish_weights               0.167
#                                              Student_grades             0.457
#           XGBoost        Linear              Boston                     0.424
#                                              Student_grades             0.478
#                          XGBoost             Boston                     0.420
#                                              Diabetes                   0.722
#                                              Student_grades             0.449
#
#                                                              Avg_Percentage_Improvement
# Data_Type Explainer_Type Ensemble_model_Type Dataset_name
# Original  Linear         Linear              Boston                            7.673564
#                          XGBoost             Amazon                            3.474731
#                                              Boston                           26.138851
#                                              Fish_weights                      2.339181
#                                              Student_grades                    7.676768
#           XGBoost        XGBoost             Amazon                            2.168865
#                                              Boston                            8.442951
#                                              Diabetes                          0.672948
#                                              NYE_Airbnb                        1.991716
#                                              Student_grades                    5.656566
# Shapley   Linear         Linear              Boston                            7.673564
#                          XGBoost             Amazon                            3.474731
#                                              Boston                           26.138851
#                                              Fish_weights                      2.339181
#                                              Student_grades                    7.676768
#           XGBoost        Linear              Boston                           18.444982
#                                              Student_grades                    3.434343
#                          XGBoost             Boston                           19.214369
#                                              Diabetes                          2.826380
#                                              Student_grades                    9.292929

# %%
data_min = benchmark_df.groupby(['Data_Type','Explainer_Type','Ensemble_model_Type','Dataset_name'])
data_min_df = data_min.agg({'Explainer_model' : min ,'Original_ensemble':min, 'Shapley_ensemble' : min})
data_real_min = data_min_df[(data_min_df['Explainer_model'] > data_min_df['Shapley_ensemble']) & (data_min_df['Original_ensemble'] > data_min_df['Shapley_ensemble'])]
bsl1_improvement = (data_real_min['Explainer_model'] - data_real_min['Shapley_ensemble']).divide(data_real_min['Explainer_model'])
bsl2_improvement = (data_real_min['Original_ensemble'] - data_real_min['Shapley_ensemble']).divide(data_real_min['Original_ensemble'])
data_real_min['Avg_Percentage_Improvement'] = 100 * (bsl1_improvement+bsl2_improvement)/2
data_real_min
# Out:
# C:\Users\koral\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                              Explainer_model  \
# Data_Type Explainer_Type Ensemble_model_Type Dataset_name
# Original  Linear         Linear              Boston                    0.545
#                          XGBoost             Amazon                    0.927
#                                              Boston                    0.545
#                                              Fish_weights              0.171
#                                              Student_grades            0.495
#           XGBoost        XGBoost             Amazon                    0.927
#                                              Boston                    0.545
#                                              Diabetes                  0.743
#                                              NYE_Airbnb                0.832
#                                              Student_grades            0.495
# Shapley   Linear         Linear              Boston                    0.545
#                          XGBoost             Amazon                    0.927
#                                              Boston                    0.545
#                                              Fish_weights              0.171
#                                              Student_grades            0.495
#           XGBoost        Linear              Boston                    0.545
#                                              Student_grades            0.495
#                          XGBoost             Boston                    0.545
#                                              Diabetes                  0.743
#                                              Student_grades            0.495
#
#                                                              Original_ensemble  \
# Data_Type Explainer_Type Ensemble_model_Type Dataset_name
# Original  Linear         Linear              Boston                      0.497
#                          XGBoost             Amazon                      0.911
#                                              Boston                      0.497
#                                              Fish_weights                0.171
#                                              Student_grades              0.495
#           XGBoost        XGBoost             Amazon                      0.911
#                                              Boston                      0.497
#                                              Diabetes                    0.743
#                                              NYE_Airbnb                  0.809
#                                              Student_grades              0.495
# Shapley   Linear         Linear              Boston                      0.497
#                          XGBoost             Amazon                      0.911
#                                              Boston                      0.497
#                                              Fish_weights                0.171
#                                              Student_grades              0.495
#           XGBoost        Linear              Boston                      0.497
#                                              Student_grades              0.495
#                          XGBoost             Boston                      0.497
#                                              Diabetes                    0.743
#                                              Student_grades              0.495
#
#                                                              Shapley_ensemble  \
# Data_Type Explainer_Type Ensemble_model_Type Dataset_name
# Original  Linear         Linear              Boston                     0.480
#                          XGBoost             Amazon                     0.887
#                                              Boston                     0.384
#                                              Fish_weights               0.167
#                                              Student_grades             0.457
#           XGBoost        XGBoost             Amazon                     0.899
#                                              Boston                     0.476
#                                              Diabetes                   0.738
#                                              NYE_Airbnb                 0.804
#                                              Student_grades             0.467
# Shapley   Linear         Linear              Boston                     0.480
#                          XGBoost             Amazon                     0.887
#                                              Boston                     0.384
#                                              Fish_weights               0.167
#                                              Student_grades             0.457
#           XGBoost        Linear              Boston                     0.424
#                                              Student_grades             0.478
#                          XGBoost             Boston                     0.420
#                                              Diabetes                   0.722
#                                              Student_grades             0.449
#
#                                                              Avg_Percentage_Improvement
# Data_Type Explainer_Type Ensemble_model_Type Dataset_name
# Original  Linear         Linear              Boston                            7.673564
#                          XGBoost             Amazon                            3.474731
#                                              Boston                           26.138851
#                                              Fish_weights                      2.339181
#                                              Student_grades                    7.676768
#           XGBoost        XGBoost             Amazon                            2.168865
#                                              Boston                            8.442951
#                                              Diabetes                          0.672948
#                                              NYE_Airbnb                        1.991716
#                                              Student_grades                    5.656566
# Shapley   Linear         Linear              Boston                            7.673564
#                          XGBoost             Amazon                            3.474731
#                                              Boston                           26.138851
#                                              Fish_weights                      2.339181
#                                              Student_grades                    7.676768
#           XGBoost        Linear              Boston                           18.444982
#                                              Student_grades                    3.434343
#                          XGBoost             Boston                           19.214369
#                                              Diabetes                          2.826380
#                                              Student_grades                    9.292929

# %%
data_real_min2 = data_real_min['Shapley_ensemble'].groupby(['Data_Type','Ensemble_model_Type','Explainer_Type']).count()
data_param_count = data_real_min2.groupby(['Data_Type','Explainer_Type','Ensemble_model_Type']).sum()
data_param_count
# Out:
# Data_Type  Explainer_Type  Ensemble_model_Type
# Original   Linear          Linear                 1
#                            XGBoost                4
#            XGBoost         XGBoost                5
# Shapley    Linear          Linear                 1
#                            XGBoost                4
#            XGBoost         Linear                 2
#                            XGBoost                3
# Name: Shapley_ensemble, dtype: int64

# %%
data_min = benchmark_df.groupby(['Data_Type','Cluster_count','Explainer_Type','Ensemble_model_Type','Dataset_name'])
data_min_df = data_min.agg({'Explainer_model' : min ,'Original_ensemble':min, 'Shapley_ensemble' : min})
data_real_min = data_min_df[(data_min_df['Explainer_model'] > data_min_df['Shapley_ensemble']) & (data_min_df['Original_ensemble'] > data_min_df['Shapley_ensemble'])]
data_real_min
# Out:
#                                                                            Explainer_model  \
# Data_Type Cluster_count Explainer_Type Ensemble_model_Type Dataset_name
# Original  3             Linear         XGBoost             Amazon                    0.927
#                                                            Fish_weights              0.171
#                                                            Student_grades            0.495
#                         XGBoost        XGBoost             Amazon                    0.927
#                                                            Boston                    0.545
#                                                            Diabetes                  0.743
#                                                            Student_grades            0.495
#           5             Linear         Linear              Boston                    0.545
#                                        XGBoost             Amazon                    0.927
#                                                            Boston                    0.545
#                         XGBoost        XGBoost             Amazon                    0.927
#                                                            Diabetes                  0.743
#                                                            NYE_Airbnb                0.832
# Shapley   1             Linear         XGBoost             Student_grades            0.495
#                         XGBoost        Linear              Student_grades            0.495
#                                        XGBoost             Student_grades            0.495
#           3             Linear         XGBoost             Amazon                    0.927
#                                                            Fish_weights              0.171
#                                                            Student_grades            0.495
#                         XGBoost        Linear              Boston                    0.545
#                                                            Student_grades            0.495
#                                        XGBoost             Boston                    0.545
#                                                            Diabetes                  0.743
#                                                            Student_grades            0.495
#           5             Linear         Linear              Boston                    0.545
#                                        XGBoost             Amazon                    0.927
#                                                            Boston                    0.545
#                         XGBoost        Linear              Boston                    0.545
#                                        XGBoost             Diabetes                  0.743
#                                                            Student_grades            0.495
#
#                                                                            Original_ensemble  \
# Data_Type Cluster_count Explainer_Type Ensemble_model_Type Dataset_name
# Original  3             Linear         XGBoost             Amazon                      0.911
#                                                            Fish_weights                0.171
#                                                            Student_grades              0.495
#                         XGBoost        XGBoost             Amazon                      0.911
#                                                            Boston                      0.497
#                                                            Diabetes                    0.743
#                                                            Student_grades              0.495
#           5             Linear         Linear              Boston                      0.497
#                                        XGBoost             Amazon                      0.911
#                                                            Boston                      0.497
#                         XGBoost        XGBoost             Amazon                      0.911
#                                                            Diabetes                    0.743
#                                                            NYE_Airbnb                  0.809
# Shapley   1             Linear         XGBoost             Student_grades              0.495
#                         XGBoost        Linear              Student_grades              0.495
#                                        XGBoost             Student_grades              0.495
#           3             Linear         XGBoost             Amazon                      0.911
#                                                            Fish_weights                0.171
#                                                            Student_grades              0.495
#                         XGBoost        Linear              Boston                      0.497
#                                                            Student_grades              0.495
#                                        XGBoost             Boston                      0.497
#                                                            Diabetes                    0.743
#                                                            Student_grades              0.495
#           5             Linear         Linear              Boston                      0.497
#                                        XGBoost             Amazon                      0.911
#                                                            Boston                      0.497
#                         XGBoost        Linear              Boston                      0.497
#                                        XGBoost             Diabetes                    0.743
#                                                            Student_grades              0.495
#
#                                                                            Shapley_ensemble
# Data_Type Cluster_count Explainer_Type Ensemble_model_Type Dataset_name
# Original  3             Linear         XGBoost             Amazon                     0.887
#                                                            Fish_weights               0.167
#                                                            Student_grades             0.457
#                         XGBoost        XGBoost             Amazon                     0.905
#                                                            Boston                     0.476
#                                                            Diabetes                   0.741
#                                                            Student_grades             0.467
#           5             Linear         Linear              Boston                     0.480
#                                        XGBoost             Amazon                     0.891
#                                                            Boston                     0.384
#                         XGBoost        XGBoost             Amazon                     0.899
#                                                            Diabetes                   0.738
#                                                            NYE_Airbnb                 0.804
# Shapley   1             Linear         XGBoost             Student_grades             0.494
#                         XGBoost        Linear              Student_grades             0.489
#                                        XGBoost             Student_grades             0.487
#           3             Linear         XGBoost             Amazon                     0.887
#                                                            Fish_weights               0.167
#                                                            Student_grades             0.457
#                         XGBoost        Linear              Boston                     0.424
#                                                            Student_grades             0.478
#                                        XGBoost             Boston                     0.420
#                                                            Diabetes                   0.738
#                                                            Student_grades             0.449
#           5             Linear         Linear              Boston                     0.480
#                                        XGBoost             Amazon                     0.891
#                                                            Boston                     0.384
#                         XGBoost        Linear              Boston                     0.437
#                                        XGBoost             Diabetes                   0.722
#                                                            Student_grades             0.494

# %%
data_real_min2 = data_real_min['Shapley_ensemble'].groupby(['Data_Type','Cluster_count','Ensemble_model_Type','Explainer_Type']).count()
data_param_count = data_real_min2.groupby(['Data_Type','Cluster_count','Explainer_Type','Ensemble_model_Type']).sum()
data_param_count
# Out:
# Data_Type  Cluster_count  Explainer_Type  Ensemble_model_Type
# Original   3              Linear          XGBoost                3
#                           XGBoost         XGBoost                4
#            5              Linear          Linear                 1
#                                           XGBoost                2
#                           XGBoost         XGBoost                3
# Shapley    1              Linear          XGBoost                1
#                           XGBoost         Linear                 1
#                                           XGBoost                1
#            3              Linear          XGBoost                3
#                           XGBoost         Linear                 2
#                                           XGBoost                3
#            5              Linear          Linear                 1
#                                           XGBoost                2
#                           XGBoost         Linear                 1
#                                           XGBoost                2
# Name: Shapley_ensemble, dtype: int64

# %%
benchmark_df = pd.read_csv('../Data/test_results_all_data.txt')
bsl1 = benchmark_df.groupby('Dataset_name').agg({'Explainer_model' : min})
bsl2 = benchmark_df.groupby('Dataset_name').agg({'Original_ensemble' : min})
for j in range(len(benchmark_df['Dataset_name'])):
    benchmark_df['Explainer_model'].iloc[j] = bsl1.loc[benchmark_df['Dataset_name'].iloc[j]][0]
    benchmark_df['Original_ensemble'].iloc[j] = bsl2.loc[benchmark_df['Dataset_name'].iloc[j]][0]
data_min = benchmark_df.groupby(['Data_Type','Explainer_Type','Ensemble_model_Type','Dataset_name'])
data_min_df = data_min.agg({'Explainer_model' : min ,'Original_ensemble':min, 'Shapley_ensemble' : min})
data_real_min = data_min_df[(data_min_df['Explainer_model'] > data_min_df['Shapley_ensemble']) & (data_min_df['Original_ensemble'] > data_min_df['Shapley_ensemble'])]
data_real_min
# Out:
#                                                              Explainer_model  \
# Data_Type Explainer_Type Ensemble_model_Type Dataset_name
# Original  Linear         Linear              Boston                    5.038
#                          XGBoost             Amazon                  177.426
#                                              Boston                    5.038
#                                              Crime                   393.516
#                                              Insurance              5645.005
#                                              NYE_Airbnb              167.116
#                                              Student_grades            2.165
#           XGBoost        Linear              Diabetes                 58.170
#                                              NYE_Airbnb              167.116
#                          XGBoost             Amazon                  177.426
#                                              Boston                    5.038
#                                              Diabetes                 58.170
#                                              Insurance              5645.005
#                                              NYE_Airbnb              167.116
#                                              Student_grades            2.165
# Shapley   Linear         Linear              Boston                    5.038
#                          XGBoost             Amazon                  177.426
#                                              Boston                    5.038
#                                              Crime                   393.516
#                                              Fish_weights             59.185
#                                              Insurance              5645.005
#                                              NYE_Airbnb              167.116
#                                              Nhanes                   11.816
#                                              Student_grades            2.165
#           XGBoost        Linear              Boston                    5.038
#                                              Fish_weights             59.185
#                                              Student_grades            2.165
#                          XGBoost             Boston                    5.038
#                                              Diabetes                 58.170
#                                              Insurance              5645.005
#                                              NYE_Airbnb              167.116
#                                              Student_grades            2.165
#
#                                                              Original_ensemble  \
# Data_Type Explainer_Type Ensemble_model_Type Dataset_name
# Original  Linear         Linear              Boston                      4.649
#                          XGBoost             Amazon                    174.219
#                                              Boston                      4.649
#                                              Crime                     389.341
#                                              Insurance                3955.984
#                                              NYE_Airbnb                166.192
#                                              Student_grades              2.165
#           XGBoost        Linear              Diabetes                   58.170
#                                              NYE_Airbnb                166.192
#                          XGBoost             Amazon                    174.219
#                                              Boston                      4.649
#                                              Diabetes                   58.170
#                                              Insurance                3955.984
#                                              NYE_Airbnb                166.192
#                                              Student_grades              2.165
# Shapley   Linear         Linear              Boston                      4.649
#                          XGBoost             Amazon                    174.219
#                                              Boston                      4.649
#                                              Crime                     389.341
#                                              Fish_weights               59.185
#                                              Insurance                3955.984
#                                              NYE_Airbnb                166.192
#                                              Nhanes                     11.816
#                                              Student_grades              2.165
#           XGBoost        Linear              Boston                      4.649
#                                              Fish_weights               59.185
#                                              Student_grades              2.165
#                          XGBoost             Boston                      4.649
#                                              Diabetes                   58.170
#                                              Insurance                3955.984
#                                              NYE_Airbnb                166.192
#                                              Student_grades              2.165
#
#                                                              Shapley_ensemble
# Data_Type Explainer_Type Ensemble_model_Type Dataset_name
# Original  Linear         Linear              Boston                     4.201
#                          XGBoost             Amazon                   169.726
#                                              Boston                     4.199
#                                              Crime                    387.230
#                                              Insurance               3933.566
#                                              NYE_Airbnb               163.401
#                                              Student_grades             1.959
#           XGBoost        Linear              Diabetes                  57.532
#                                              NYE_Airbnb               165.820
#                          XGBoost             Amazon                   171.623
#                                              Boston                     4.177
#                                              Diabetes                  56.947
#                                              Insurance               3950.049
#                                              NYE_Airbnb               161.415
#                                              Student_grades             2.010
# Shapley   Linear         Linear              Boston                     4.201
#                          XGBoost             Amazon                   169.726
#                                              Boston                     4.192
#                                              Crime                    387.196
#                                              Fish_weights              59.159
#                                              Insurance               3934.833
#                                              NYE_Airbnb               163.270
#                                              Nhanes                    11.815
#                                              Student_grades             1.959
#           XGBoost        Linear              Boston                     3.843
#                                              Fish_weights              51.788
#                                              Student_grades             2.007
#                          XGBoost             Boston                     3.810
#                                              Diabetes                  57.086
#                                              Insurance               3916.729
#                                              NYE_Airbnb               165.177
#                                              Student_grades             1.898

# %%
data_real_min2 = data_real_min['Shapley_ensemble'].groupby(['Data_Type','Ensemble_model_Type','Explainer_Type']).count()
data_param_count = data_real_min2.groupby(['Data_Type','Explainer_Type','Ensemble_model_Type']).sum()
data_param_count
# Out:
# Data_Type  Explainer_Type  Ensemble_model_Type
# Original   Linear          Linear                 1
#                            XGBoost                6
#            XGBoost         Linear                 2
#                            XGBoost                6
# Shapley    Linear          Linear                 1
#                            XGBoost                8
#            XGBoost         Linear                 3
#                            XGBoost                5
# Name: Shapley_ensemble, dtype: int64

# %%
data_min = benchmark_df.groupby(['Data_Type','Cluster_count','Explainer_Type','Ensemble_model_Type','Dataset_name'])
data_min_df = data_min.agg({'Explainer_model' : min ,'Original_ensemble':min, 'Shapley_ensemble' : min})
data_real_min = data_min_df[(data_min_df['Explainer_model'] > data_min_df['Shapley_ensemble']) & (data_min_df['Original_ensemble'] > data_min_df['Shapley_ensemble'])]
data_real_min
# Out:
#                                                                            Explainer_model  \
# Data_Type Cluster_count Explainer_Type Ensemble_model_Type Dataset_name
# Original  3             Linear         XGBoost             Amazon                  177.426
#                                                            Insurance              5645.005
#                                                            NYE_Airbnb              167.116
#                                                            Student_grades            2.165
#                         XGBoost        Linear              Diabetes                 58.170
#                                        XGBoost             Amazon                  177.426
#                                                            Boston                    5.038
#                                                            Diabetes                 58.170
#                                                            Insurance              5645.005
#                                                            NYE_Airbnb              167.116
#                                                            Student_grades            2.165
#           5             Linear         Linear              Boston                    5.038
#                                        XGBoost             Amazon                  177.426
#                                                            Boston                    5.038
#                                                            Crime                   393.516
#                                                            Insurance              5645.005
#                                                            NYE_Airbnb              167.116
#                         XGBoost        Linear              NYE_Airbnb              167.116
#                                        XGBoost             Amazon                  177.426
#                                                            NYE_Airbnb              167.116
#                                                            Student_grades            2.165
# Shapley   1             Linear         XGBoost             Fish_weights             59.185
#                                                            Nhanes                   11.816
#                         XGBoost        Linear              Student_grades            2.165
#                                        XGBoost             Student_grades            2.165
#           3             Linear         XGBoost             Amazon                  177.426
#                                                            Insurance              5645.005
#                                                            NYE_Airbnb              167.116
#                                                            Student_grades            2.165
#                         XGBoost        Linear              Boston                    5.038
#                                                            Fish_weights             59.185
#                                                            Student_grades            2.165
#                                        XGBoost             Boston                    5.038
#                                                            Diabetes                 58.170
#                                                            Insurance              5645.005
#                                                            NYE_Airbnb              167.116
#                                                            Student_grades            2.165
#           5             Linear         Linear              Boston                    5.038
#                                        XGBoost             Amazon                  177.426
#                                                            Boston                    5.038
#                                                            Crime                   393.516
#                                                            Insurance              5645.005
#                                                            NYE_Airbnb              167.116
#                         XGBoost        Linear              Boston                    5.038
#                                                            Student_grades            2.165
#                                        XGBoost             Insurance              5645.005
#                                                            NYE_Airbnb              167.116
#                                                            Student_grades            2.165
#
#                                                                            Original_ensemble  \
# Data_Type Cluster_count Explainer_Type Ensemble_model_Type Dataset_name
# Original  3             Linear         XGBoost             Amazon                    174.219
#                                                            Insurance                3955.984
#                                                            NYE_Airbnb                166.192
#                                                            Student_grades              2.165
#                         XGBoost        Linear              Diabetes                   58.170
#                                        XGBoost             Amazon                    174.219
#                                                            Boston                      4.649
#                                                            Diabetes                   58.170
#                                                            Insurance                3955.984
#                                                            NYE_Airbnb                166.192
#                                                            Student_grades              2.165
#           5             Linear         Linear              Boston                      4.649
#                                        XGBoost             Amazon                    174.219
#                                                            Boston                      4.649
#                                                            Crime                     389.341
#                                                            Insurance                3955.984
#                                                            NYE_Airbnb                166.192
#                         XGBoost        Linear              NYE_Airbnb                166.192
#                                        XGBoost             Amazon                    174.219
#                                                            NYE_Airbnb                166.192
#                                                            Student_grades              2.165
# Shapley   1             Linear         XGBoost             Fish_weights               59.185
#                                                            Nhanes                     11.816
#                         XGBoost        Linear              Student_grades              2.165
#                                        XGBoost             Student_grades              2.165
#           3             Linear         XGBoost             Amazon                    174.219
#                                                            Insurance                3955.984
#                                                            NYE_Airbnb                166.192
#                                                            Student_grades              2.165
#                         XGBoost        Linear              Boston                      4.649
#                                                            Fish_weights               59.185
#                                                            Student_grades              2.165
#                                        XGBoost             Boston                      4.649
#                                                            Diabetes                   58.170
#                                                            Insurance                3955.984
#                                                            NYE_Airbnb                166.192
#                                                            Student_grades              2.165
#           5             Linear         Linear              Boston                      4.649
#                                        XGBoost             Amazon                    174.219
#                                                            Boston                      4.649
#                                                            Crime                     389.341
#                                                            Insurance                3955.984
#                                                            NYE_Airbnb                166.192
#                         XGBoost        Linear              Boston                      4.649
#                                                            Student_grades              2.165
#                                        XGBoost             Insurance                3955.984
#                                                            NYE_Airbnb                166.192
#                                                            Student_grades              2.165
#
#                                                                            Shapley_ensemble
# Data_Type Cluster_count Explainer_Type Ensemble_model_Type Dataset_name
# Original  3             Linear         XGBoost             Amazon                   169.726
#                                                            Insurance               3946.564
#                                                            NYE_Airbnb               163.612
#                                                            Student_grades             1.959
#                         XGBoost        Linear              Diabetes                  57.532
#                                        XGBoost             Amazon                   172.553
#                                                            Boston                     4.177
#                                                            Diabetes                  56.947
#                                                            Insurance               3950.049
#                                                            NYE_Airbnb               163.383
#                                                            Student_grades             2.118
#           5             Linear         Linear              Boston                     4.201
#                                        XGBoost             Amazon                   172.240
#                                                            Boston                     4.199
#                                                            Crime                    387.230
#                                                            Insurance               3933.566
#                                                            NYE_Airbnb               163.401
#                         XGBoost        Linear              NYE_Airbnb               165.820
#                                        XGBoost             Amazon                   171.623
#                                                            NYE_Airbnb               161.415
#                                                            Student_grades             2.010
# Shapley   1             Linear         XGBoost             Fish_weights              59.159
#                                                            Nhanes                    11.815
#                         XGBoost        Linear              Student_grades             2.130
#                                        XGBoost             Student_grades             2.143
#           3             Linear         XGBoost             Amazon                   169.726
#                                                            Insurance               3947.086
#                                                            NYE_Airbnb               163.613
#                                                            Student_grades             1.959
#                         XGBoost        Linear              Boston                     3.843
#                                                            Fish_weights              51.788
#                                                            Student_grades             2.067
#                                        XGBoost             Boston                     3.810
#                                                            Diabetes                  57.086
#                                                            Insurance               3916.729
#                                                            NYE_Airbnb               165.484
#                                                            Student_grades             2.056
#           5             Linear         Linear              Boston                     4.201
#                                        XGBoost             Amazon                   172.240
#                                                            Boston                     4.192
#                                                            Crime                    387.196
#                                                            Insurance               3934.833
#                                                            NYE_Airbnb               163.270
#                         XGBoost        Linear              Boston                     4.258
#                                                            Student_grades             2.007
#                                        XGBoost             Insurance               3923.297
#                                                            NYE_Airbnb               165.177
#                                                            Student_grades             1.898

# %%
data_real_min2 = data_real_min['Shapley_ensemble'].groupby(['Data_Type','Cluster_count','Ensemble_model_Type','Explainer_Type']).count()
data_param_count = data_real_min2.groupby(['Data_Type','Cluster_count','Explainer_Type','Ensemble_model_Type']).sum()
data_param_count
# Out:
# Data_Type  Cluster_count  Explainer_Type  Ensemble_model_Type
# Original   3              Linear          XGBoost                4
#                           XGBoost         Linear                 1
#                                           XGBoost                6
#            5              Linear          Linear                 1
#                                           XGBoost                5
#                           XGBoost         Linear                 1
#                                           XGBoost                3
# Shapley    1              Linear          XGBoost                2
#                           XGBoost         Linear                 1
#                                           XGBoost                1
#            3              Linear          XGBoost                4
#                           XGBoost         Linear                 3
#                                           XGBoost                5
#            5              Linear          Linear                 1
#                                           XGBoost                5
#                           XGBoost         Linear                 2
#                                           XGBoost                3
# Name: Shapley_ensemble, dtype: int64

# %%
benchmark_df_bst = benchmark_df_min[benchmark_df_min['Dataset_name'] == 'Amazon']
benchmark_df_org = benchmark_df_bst[(benchmark_df_bst['Data_Type'] == 'Original')]
benchmark_df_shap = benchmark_df_bst[(benchmark_df_bst['Data_Type'] == 'Shapley')]
benchmark_df_org.reset_index(inplace = True)
benchmark_df_shap.reset_index(inplace = True)

# %%
benchmark_melted_org = pd.melt(benchmark_df_org.iloc[:,[2,3,4,5,7,8]] , id_vars = ['Explainer_Type','Ensemble_model_Type','Cluster_count'], value_vars= ['Explainer_model','Original_ensemble','Shapley_ensemble'])
#benchmark_melted_org.drop_duplicates(benchmark_melted_org.columns[[0,3,4]],inplace = True)
benchmark_melted_org.rename(columns = {'variable':'Model','value':'rmse'},inplace = True)
g= sns.catplot(x = 'Explainer_Type',y = 'rmse', hue = 'Model',col = 'Ensemble_model_Type',row = 'Cluster_count',kind = 'bar',data = benchmark_melted_org)
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle('Test-rmse results for dataset: {0} with training via: {1}'.format(benchmark_df_org['Dataset_name'].iloc[0], benchmark_df_org['Data_Type'].iloc[0]), fontsize=16)
# Out:
# Text(0.5, 0.98, 'Test-rmse results for dataset: Amazon with training via: Original')

# %%
benchmark_melted_shap = pd.melt(benchmark_df_shap.iloc[:,[2,3,4,5,7,8]] , id_vars = ['Explainer_Type','Ensemble_model_Type','Cluster_count'], value_vars= ['Explainer_model','Original_ensemble','Shapley_ensemble'])
#benchmark_melted_shap.drop_duplicates(benchmark_melted_shap.columns[[0,3,4]],inplace = True)
benchmark_melted_shap.rename(columns = {'variable':'Model','value':'rmse'},inplace = True)
g= sns.catplot(x = 'Explainer_Type',y = 'rmse', hue = 'Model',col = 'Ensemble_model_Type',row = 'Cluster_count',kind = 'bar',data = benchmark_melted_shap)
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle('Test-rmse results for dataset: {0} with training via: {1}'.format(benchmark_df_shap['Dataset_name'].iloc[0], benchmark_df_shap['Data_Type'].iloc[0]), fontsize=16)
# Out:
# Text(0.5, 0.98, 'Test-rmse results for dataset: Amazon with training via: Shapley')

# %%
print("{0:.2f}".format(3.54662))
